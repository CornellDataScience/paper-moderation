# %%
# !pip install pandas

# %%
import pandas as pd

# %%
# 10k rows from https://huggingface.co/datasets/Cohere/wikipedia-22-12/viewer/en
df_wiki = pd.read_parquet("wikipedia_sections.parquet")
df_wiki.head()
# Out:
#    id           title                                               text  \
# 0   0  Deaths in 2022  The following notable deaths occurred in 2022....
# 1   1         YouTube  YouTube is a global online video sharing and s...
# 2   2         YouTube  In October 2006, YouTube was bought by Google ...
# 3   3         YouTube  Since its purchase by Google, YouTube has expa...
# 4   4         YouTube  YouTube has had an unprecedented social impact...
#
#                                             url   wiki_id        views  \
# 0  https://en.wikipedia.org/wiki?curid=69407798  69407798  5674.449219
# 1   https://en.wikipedia.org/wiki?curid=3524766   3524766  5409.561035
# 2   https://en.wikipedia.org/wiki?curid=3524766   3524766  5409.561035
# 3   https://en.wikipedia.org/wiki?curid=3524766   3524766  5409.561035
# 4   https://en.wikipedia.org/wiki?curid=3524766   3524766  5409.561035
#
#    paragraph_id  langs
# 0             0     38
# 1             0    184
# 2             1    184
# ...

# %%
# 4k rows from https://huggingface.co/datasets/mlcore/arxiv-classifier
df_arxiv = pd.read_parquet("arxiv.parquet")
df_arxiv.head()
# Out:
#      paper_id version  yymm             created  \
# 0  1501.03486       2  1501 2015-01-16 10:15:42
# 1   0908.4485       2  0908 2010-03-15 10:35:23
# 2   1007.3144       1  1007 2010-07-19 13:24:01
# 3  1607.04802       2  1607 2016-09-07 10:45:25
# 4   1109.0619       1  1109 2011-09-03 13:19:56
#
#                                                title  \
# 0  A spin-wave logic gate based on a width-modula...
# 1  Discontinuous Euler instability in nanoelectro...
# 2  Polarization dependence of coherent phonon gen...
# 3  Heat production and error probability relation...
# 4  Magnetic Fields Effects on the Electronic Cond...
#
#                         secondary_subfield  \
# 0                      [cond-mat.mes-hall]
# 1                      [cond-mat.mes-hall]
# 2                      [cond-mat.mes-hall]
# 3  [cond-mat.mes-hall, cond-mat.stat-mech]
# 4                      [cond-mat.mes-hall]
#
#                                             abstract   primary_subfield  \
# ...
