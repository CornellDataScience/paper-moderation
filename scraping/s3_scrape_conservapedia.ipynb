# %%
import boto3
import os
import time
import requests
from bs4 import BeautifulSoup
from urllib.parse import urljoin
from requests.adapters import HTTPAdapter
from urllib3.util.retry import Retry

# %%
# Creating an S3 access object
obj = boto3.client("s3")

# %%
def fetch_links(base_url, start_url, max_articles=50):
    """
    Crawls Conservapedia to gather article links.
    
    Args:
        base_url (str): The base URL of Conservapedia.
        start_url (str): The starting URL for crawling.
        max_articles (int): Maximum number of articles to crawl.
    
    Returns:
        list: A list of article URLs.
    """
    visited = set()
    to_visit = [start_url]
    article_links = []

    # Setup session with retries
    session = requests.Session()
    retries = Retry(total=5, backoff_factor=1, status_forcelist=[429, 500, 502, 503, 504])
    adapter = HTTPAdapter(max_retries=retries)
    session.mount("https://", adapter)
    session.mount("http://", adapter)

    headers = {
        "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/114.0.0.0 Safari/537.36"
    }

    while to_visit and len(article_links) < max_articles:
        current_url = to_visit.pop(0)
        if current_url in visited:
            continue

        try:
            response = session.get(current_url, headers=headers, timeout=10)
            response.raise_for_status()
            soup = BeautifulSoup(response.text, 'html.parser')

            visited.add(current_url)

            for link in soup.find_all('a', href=True):
                href = link['href']
                full_url = urljoin(base_url, href)
                if full_url.startswith(base_url) and ":" not in href and full_url not in visited:
                    to_visit.append(full_url)
                    article_links.append(full_url)
                    if len(article_links) >= max_articles:
                        break

            time.sleep(2)  # Politeness delay

        except requests.exceptions.RequestException as e:
            print(f"Error fetching {current_url}: {e}")
            continue
    article_links = [ x for x in article_links if '#' not in x ]
    return article_links

def scrape_article(url, session, headers):
    """
    Scrapes the main text content of a Conservapedia article.
    
    Args:
        url (str): The URL of the Conservapedia article.
        session: The session object with retry logic.
        headers (dict): Headers for the request.
    
    Returns:
        str: The text content of the article.
    """
    try:
        response = session.get(url, headers=headers, timeout=10)
        response.raise_for_status()
        soup = BeautifulSoup(response.text, 'html.parser')
        content_div = soup.find('div', {'id': 'bodyContent'})

        if not content_div:
            return "Main content area not found."
        
        paragraphs = content_div.find_all('p')
        return "\n".join(p.get_text(strip=True) for p in paragraphs)

    except requests.exceptions.RequestException as e:
        return f"Error fetching the URL: {e}"
    except Exception as e:
        return f"An error occurred: {e}"

def save_to_txt(content, filename):
    """
    Saves scraped article content to a .txt file.
    
    Args:
        content (str): The text content of the article.
        filename (str): Name of the file to save the content.
    """
    with open(filename, 'w', encoding='utf-8') as file:
        file.write(content)

def send_to_s3(filename):
    obj.upload_file(
    Filename= filename,
    Bucket="arxivpapers",
    Key="conservapedia_papers/"+filename
)

# %%
if __name__ == "__main__":
    base_url = "https://www.conservapedia.com"
    start_url = f"{base_url}/Main_Page"
    max_articles = 20000  # Change as needed
    output_dir = "conservapedia_articles"
    os.makedirs(output_dir, exist_ok=True)

    # Setup session with retries
    session = requests.Session()
    retries = Retry(total=5, backoff_factor=1, status_forcelist=[429, 500, 502, 503, 504])
    adapter = HTTPAdapter(max_retries=retries)
    session.mount("https://", adapter)
    session.mount("http://", adapter)

    headers = {
        "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/114.0.0.0 Safari/537.36"
    }

    print("Fetching article links...")
    article_links = fetch_links(base_url, start_url, max_articles)
    #print(article_links)
    print(f"Found {len(article_links)} articles. Scraping content...")

    for idx, article_url in enumerate(article_links, start=1):
        print(f"\n--- Scraping Article {idx} ---")
        article_text = scrape_article(article_url, session, headers)
        article_title = article_url.split("/")[-1]
        filename = os.path.join(output_dir, f"{article_title}.txt")
        shortname = f"{article_title}.txt"
        save_to_txt(article_text, shortname)
        #print(f"Saved: {shortname}")
        send_to_s3(shortname)
        os.remove(shortname)
# Out:
# Fetching article links...
# Found 13787 articles. Scraping content...
#
# --- Scraping Article 1 ---
#
# --- Scraping Article 2 ---
#
# --- Scraping Article 3 ---
#
# --- Scraping Article 4 ---
#
# --- Scraping Article 5 ---
#
# --- Scraping Article 6 ---
#
# --- Scraping Article 7 ---
#
# --- Scraping Article 8 ---
#
# --- Scraping Article 9 ---
#
# --- Scraping Article 10 ---
#
# --- Scraping Article 11 ---
#
# --- Scraping Article 12 ---
#
# --- Scraping Article 13 ---
#
# --- Scraping Article 14 ---
#
# --- Scraping Article 15 ---
#
# --- Scraping Article 16 ---
#
# --- Scraping Article 17 ---
#
# --- Scraping Article 18 ---
#
# --- Scraping Article 19 ---
#
# --- Scraping Article 20 ---
#
# --- Scraping Article 21 ---
#
# --- Scraping Article 22 ---
#
# --- Scraping Article 23 ---
#
# --- Scraping Article 24 ---
#
# --- Scraping Article 25 ---
#
# --- Scraping Article 26 ---
#
# --- Scraping Article 27 ---
#
# --- Scraping Article 28 ---
#
# --- Scraping Article 29 ---
#
# --- Scraping Article 30 ---
#
# --- Scraping Article 31 ---
#
# --- Scraping Article 32 ---
#
# --- Scraping Article 33 ---
#
# --- Scraping Article 34 ---
#
# --- Scraping Article 35 ---
#
# --- Scraping Article 36 ---
#
# --- Scraping Article 37 ---
#
# --- Scraping Article 38 ---
#
# --- Scraping Article 39 ---
#
# --- Scraping Article 40 ---
#
# --- Scraping Article 41 ---
#
# --- Scraping Article 42 ---
#
# --- Scraping Article 43 ---
#
# --- Scraping Article 44 ---
#
# --- Scraping Article 45 ---
#
# --- Scraping Article 46 ---
#
# --- Scraping Article 47 ---
#
# --- Scraping Article 48 ---
#
# --- Scraping Article 49 ---
#
# --- Scraping Article 50 ---
#
# --- Scraping Article 51 ---
#
# --- Scraping Article 52 ---
#
# --- Scraping Article 53 ---
#
# --- Scraping Article 54 ---
#
# --- Scraping Article 55 ---
#
# --- Scraping Article 56 ---
#
# --- Scraping Article 57 ---
#
# --- Scraping Article 58 ---
#
# --- Scraping Article 59 ---
#
# --- Scraping Article 60 ---
#
# --- Scraping Article 61 ---
#
# --- Scraping Article 62 ---
#
# --- Scraping Article 63 ---
#
# --- Scraping Article 64 ---
#
# --- Scraping Article 65 ---
#
# --- Scraping Article 66 ---
#
# --- Scraping Article 67 ---
#
# --- Scraping Article 68 ---
#
# --- Scraping Article 69 ---
#
# --- Scraping Article 70 ---
#
# --- Scraping Article 71 ---
#
# --- Scraping Article 72 ---
#
# --- Scraping Article 73 ---
#
# --- Scraping Article 74 ---
#
# --- Scraping Article 75 ---
#
# --- Scraping Article 76 ---
#
# --- Scraping Article 77 ---
#
# --- Scraping Article 78 ---
#
# --- Scraping Article 79 ---
#
# --- Scraping Article 80 ---
#
# --- Scraping Article 81 ---
#
# --- Scraping Article 82 ---
#
# --- Scraping Article 83 ---
#
# --- Scraping Article 84 ---
#
# --- Scraping Article 85 ---
#
# --- Scraping Article 86 ---
#
# --- Scraping Article 87 ---
#
# --- Scraping Article 88 ---
#
# --- Scraping Article 89 ---
#
# --- Scraping Article 90 ---
#
# --- Scraping Article 91 ---
#
# --- Scraping Article 92 ---
#
# --- Scraping Article 93 ---
#
# --- Scraping Article 94 ---
#
# --- Scraping Article 95 ---
#
# --- Scraping Article 96 ---
#
# --- Scraping Article 97 ---
#
# --- Scraping Article 98 ---
#
# --- Scraping Article 99 ---
#
# --- Scraping Article 100 ---
#
# --- Scraping Article 101 ---
#
# --- Scraping Article 102 ---
#
# --- Scraping Article 103 ---
#
# --- Scraping Article 104 ---
#
# --- Scraping Article 105 ---
#
# --- Scraping Article 106 ---
#
# --- Scraping Article 107 ---
#
# --- Scraping Article 108 ---
#
# --- Scraping Article 109 ---
#
# --- Scraping Article 110 ---
#
# --- Scraping Article 111 ---
#
# --- Scraping Article 112 ---
#
# --- Scraping Article 113 ---
#
# --- Scraping Article 114 ---
#
# --- Scraping Article 115 ---
#
# --- Scraping Article 116 ---
#
# --- Scraping Article 117 ---
#
# --- Scraping Article 118 ---
#
# --- Scraping Article 119 ---
#
# --- Scraping Article 120 ---
#
# --- Scraping Article 121 ---
#
# --- Scraping Article 122 ---
#
# --- Scraping Article 123 ---
#
# --- Scraping Article 124 ---
#
# --- Scraping Article 125 ---
#
# --- Scraping Article 126 ---
#
# --- Scraping Article 127 ---
#
# --- Scraping Article 128 ---
#
# --- Scraping Article 129 ---
#
# --- Scraping Article 130 ---
#
# --- Scraping Article 131 ---
#
# --- Scraping Article 132 ---
#
# --- Scraping Article 133 ---
#
# --- Scraping Article 134 ---
#
# --- Scraping Article 135 ---
#
# --- Scraping Article 136 ---
#
# --- Scraping Article 137 ---
#
# --- Scraping Article 138 ---
#
# --- Scraping Article 139 ---
#
# --- Scraping Article 140 ---
#
# --- Scraping Article 141 ---
#
# --- Scraping Article 142 ---
#
# --- Scraping Article 143 ---
#
# --- Scraping Article 144 ---
#
# --- Scraping Article 145 ---
#
# --- Scraping Article 146 ---
#
# --- Scraping Article 147 ---
#
# --- Scraping Article 148 ---
#
# --- Scraping Article 149 ---
#
# --- Scraping Article 150 ---
#
# --- Scraping Article 151 ---
#
# --- Scraping Article 152 ---
#
# --- Scraping Article 153 ---
#
# --- Scraping Article 154 ---
#
# --- Scraping Article 155 ---
#
# --- Scraping Article 156 ---
#
# --- Scraping Article 157 ---
#
# --- Scraping Article 158 ---
#
# --- Scraping Article 159 ---
#
# --- Scraping Article 160 ---
#
# --- Scraping Article 161 ---
#
# --- Scraping Article 162 ---
#
# --- Scraping Article 163 ---
#
# --- Scraping Article 164 ---
#
# --- Scraping Article 165 ---
#
# --- Scraping Article 166 ---
#
# --- Scraping Article 167 ---
#
# --- Scraping Article 168 ---
#
# --- Scraping Article 169 ---
#
# --- Scraping Article 170 ---
#
# --- Scraping Article 171 ---
#
# --- Scraping Article 172 ---
#
# --- Scraping Article 173 ---
#
# --- Scraping Article 174 ---
#
# --- Scraping Article 175 ---
#
# --- Scraping Article 176 ---
#
# --- Scraping Article 177 ---
#
# --- Scraping Article 178 ---
#
# --- Scraping Article 179 ---
#
# --- Scraping Article 180 ---
#
# --- Scraping Article 181 ---
#
# --- Scraping Article 182 ---
#
# --- Scraping Article 183 ---
#
# --- Scraping Article 184 ---
#
# --- Scraping Article 185 ---
#
# --- Scraping Article 186 ---
#
# --- Scraping Article 187 ---
#
# --- Scraping Article 188 ---
#
# --- Scraping Article 189 ---
#
# --- Scraping Article 190 ---
#
# --- Scraping Article 191 ---
#
# --- Scraping Article 192 ---
#
# --- Scraping Article 193 ---
#
# --- Scraping Article 194 ---
#
# --- Scraping Article 195 ---
#
# --- Scraping Article 196 ---
#
# --- Scraping Article 197 ---
#
# --- Scraping Article 198 ---
#
# --- Scraping Article 199 ---
#
# --- Scraping Article 200 ---
#
# --- Scraping Article 201 ---
#
# --- Scraping Article 202 ---
#
# --- Scraping Article 203 ---
#
# --- Scraping Article 204 ---
#
# --- Scraping Article 205 ---
#
# --- Scraping Article 206 ---
#
# --- Scraping Article 207 ---
#
# --- Scraping Article 208 ---
#
# --- Scraping Article 209 ---
#
# --- Scraping Article 210 ---
#
# --- Scraping Article 211 ---
#
# --- Scraping Article 212 ---
#
# --- Scraping Article 213 ---
#
# --- Scraping Article 214 ---
#
# --- Scraping Article 215 ---
#
# --- Scraping Article 216 ---
#
# --- Scraping Article 217 ---
#
# --- Scraping Article 218 ---
#
# --- Scraping Article 219 ---
#
# --- Scraping Article 220 ---
#
# --- Scraping Article 221 ---
#
# --- Scraping Article 222 ---
#
# --- Scraping Article 223 ---
#
# --- Scraping Article 224 ---
#
# --- Scraping Article 225 ---
#
# --- Scraping Article 226 ---
#
# --- Scraping Article 227 ---
#
# --- Scraping Article 228 ---
#
# --- Scraping Article 229 ---
#
# --- Scraping Article 230 ---
#
# --- Scraping Article 231 ---
#
# --- Scraping Article 232 ---
#
# --- Scraping Article 233 ---
#
# --- Scraping Article 234 ---
#
# --- Scraping Article 235 ---
#
# --- Scraping Article 236 ---
#
# --- Scraping Article 237 ---
#
# --- Scraping Article 238 ---
#
# --- Scraping Article 239 ---
#
# --- Scraping Article 240 ---
#
# --- Scraping Article 241 ---
#
# --- Scraping Article 242 ---
#
# --- Scraping Article 243 ---
#
# --- Scraping Article 244 ---
#
# --- Scraping Article 245 ---
#
# --- Scraping Article 246 ---
#
# --- Scraping Article 247 ---
#
# --- Scraping Article 248 ---
#
# --- Scraping Article 249 ---
#
# --- Scraping Article 250 ---
#
# --- Scraping Article 251 ---
#
# --- Scraping Article 252 ---
#
# --- Scraping Article 253 ---
#
# --- Scraping Article 254 ---
#
# --- Scraping Article 255 ---
#
# --- Scraping Article 256 ---
#
# --- Scraping Article 257 ---
#
# --- Scraping Article 258 ---
#
# --- Scraping Article 259 ---
#
# --- Scraping Article 260 ---
#
# --- Scraping Article 261 ---
#
# --- Scraping Article 262 ---
#
# --- Scraping Article 263 ---
#
# --- Scraping Article 264 ---
#
# --- Scraping Article 265 ---
#
# --- Scraping Article 266 ---
#
# --- Scraping Article 267 ---
#
# --- Scraping Article 268 ---
#
# --- Scraping Article 269 ---
#
# --- Scraping Article 270 ---
#
# --- Scraping Article 271 ---
#
# --- Scraping Article 272 ---
#
# --- Scraping Article 273 ---
#
# --- Scraping Article 274 ---
#
# --- Scraping Article 275 ---
#
# --- Scraping Article 276 ---
#
# --- Scraping Article 277 ---
#
# --- Scraping Article 278 ---
#
# --- Scraping Article 279 ---
#
# --- Scraping Article 280 ---
#
# --- Scraping Article 281 ---
#
# --- Scraping Article 282 ---
#
# --- Scraping Article 283 ---
#
# --- Scraping Article 284 ---
#
# --- Scraping Article 285 ---
#
# --- Scraping Article 286 ---
#
# --- Scraping Article 287 ---
#
# --- Scraping Article 288 ---
#
# --- Scraping Article 289 ---
#
# --- Scraping Article 290 ---
#
# --- Scraping Article 291 ---
#
# --- Scraping Article 292 ---
#
# --- Scraping Article 293 ---
#
# --- Scraping Article 294 ---
#
# --- Scraping Article 295 ---
#
# --- Scraping Article 296 ---
#
# --- Scraping Article 297 ---
#
# --- Scraping Article 298 ---
#
# --- Scraping Article 299 ---
#
# --- Scraping Article 300 ---
#
# --- Scraping Article 301 ---
#
# --- Scraping Article 302 ---
#
# --- Scraping Article 303 ---
#
# --- Scraping Article 304 ---
#
# --- Scraping Article 305 ---
#
# --- Scraping Article 306 ---
#
# --- Scraping Article 307 ---
#
# --- Scraping Article 308 ---
#
# --- Scraping Article 309 ---
#
# --- Scraping Article 310 ---
#
# --- Scraping Article 311 ---
#
# --- Scraping Article 312 ---
#
# --- Scraping Article 313 ---
#
# --- Scraping Article 314 ---
#
# --- Scraping Article 315 ---
#
# --- Scraping Article 316 ---
#
# --- Scraping Article 317 ---
#
# --- Scraping Article 318 ---
#
# --- Scraping Article 319 ---
#
# --- Scraping Article 320 ---
#
# --- Scraping Article 321 ---
#
# --- Scraping Article 322 ---
#
# --- Scraping Article 323 ---
#
# --- Scraping Article 324 ---
#
# --- Scraping Article 325 ---
#
# --- Scraping Article 326 ---
#
# --- Scraping Article 327 ---
#
# --- Scraping Article 328 ---
#
# --- Scraping Article 329 ---
#
# --- Scraping Article 330 ---
#
# --- Scraping Article 331 ---
#
# --- Scraping Article 332 ---
#
# --- Scraping Article 333 ---
#
# --- Scraping Article 334 ---
#
# --- Scraping Article 335 ---
#
# --- Scraping Article 336 ---
#
# --- Scraping Article 337 ---
#
# --- Scraping Article 338 ---
#
# --- Scraping Article 339 ---
#
# --- Scraping Article 340 ---
#
# --- Scraping Article 341 ---
#
# --- Scraping Article 342 ---
#
# --- Scraping Article 343 ---
#
# --- Scraping Article 344 ---
#
# --- Scraping Article 345 ---
#
# --- Scraping Article 346 ---
#
# --- Scraping Article 347 ---
#
# --- Scraping Article 348 ---
#
# --- Scraping Article 349 ---
#
# --- Scraping Article 350 ---
#
# --- Scraping Article 351 ---
#
# --- Scraping Article 352 ---
#
# --- Scraping Article 353 ---
#
# --- Scraping Article 354 ---
#
# --- Scraping Article 355 ---
#
# --- Scraping Article 356 ---
#
# --- Scraping Article 357 ---
#
# --- Scraping Article 358 ---
#
# --- Scraping Article 359 ---
#
# --- Scraping Article 360 ---
#
# --- Scraping Article 361 ---
#
# --- Scraping Article 362 ---
#
# --- Scraping Article 363 ---
#
# --- Scraping Article 364 ---
#
# --- Scraping Article 365 ---
#
# --- Scraping Article 366 ---
#
# --- Scraping Article 367 ---
#
# --- Scraping Article 368 ---
#
# --- Scraping Article 369 ---
#
# --- Scraping Article 370 ---
#
# --- Scraping Article 371 ---
#
# --- Scraping Article 372 ---
#
# --- Scraping Article 373 ---
#
# --- Scraping Article 374 ---
#
# --- Scraping Article 375 ---
#
# --- Scraping Article 376 ---
#
# --- Scraping Article 377 ---
#
# --- Scraping Article 378 ---
#
# --- Scraping Article 379 ---
#
# --- Scraping Article 380 ---
#
# --- Scraping Article 381 ---
#
# --- Scraping Article 382 ---
#
# --- Scraping Article 383 ---
#
# --- Scraping Article 384 ---
#
# --- Scraping Article 385 ---
#
# --- Scraping Article 386 ---
#
# --- Scraping Article 387 ---
#
# --- Scraping Article 388 ---
#
# --- Scraping Article 389 ---
#
# --- Scraping Article 390 ---
#
# --- Scraping Article 391 ---
#
# --- Scraping Article 392 ---
#
# --- Scraping Article 393 ---
#
# --- Scraping Article 394 ---
#
# --- Scraping Article 395 ---
#
# --- Scraping Article 396 ---
#
# --- Scraping Article 397 ---
#
# --- Scraping Article 398 ---
#
# --- Scraping Article 399 ---
#
# --- Scraping Article 400 ---
#
# --- Scraping Article 401 ---
#
# --- Scraping Article 402 ---
#
# --- Scraping Article 403 ---
#
# --- Scraping Article 404 ---
#
# --- Scraping Article 405 ---
#
# --- Scraping Article 406 ---
#
# --- Scraping Article 407 ---
#
# --- Scraping Article 408 ---
#
# --- Scraping Article 409 ---
#
# --- Scraping Article 410 ---
#
# --- Scraping Article 411 ---
#
# --- Scraping Article 412 ---
#
# --- Scraping Article 413 ---
#
# --- Scraping Article 414 ---
#
# --- Scraping Article 415 ---
#
# --- Scraping Article 416 ---
#
# --- Scraping Article 417 ---
#
# --- Scraping Article 418 ---
#
# --- Scraping Article 419 ---
#
# --- Scraping Article 420 ---
#
# --- Scraping Article 421 ---
#
# --- Scraping Article 422 ---
#
# --- Scraping Article 423 ---
#
# --- Scraping Article 424 ---
#
# --- Scraping Article 425 ---
#
# --- Scraping Article 426 ---
#
# --- Scraping Article 427 ---
#
# --- Scraping Article 428 ---
#
# --- Scraping Article 429 ---
#
# --- Scraping Article 430 ---
#
# --- Scraping Article 431 ---
#
# --- Scraping Article 432 ---
#
# --- Scraping Article 433 ---
#
# --- Scraping Article 434 ---
#
# --- Scraping Article 435 ---
#
# --- Scraping Article 436 ---
#
# --- Scraping Article 437 ---
#
# --- Scraping Article 438 ---
#
# --- Scraping Article 439 ---
#
# --- Scraping Article 440 ---
#
# --- Scraping Article 441 ---
#
# --- Scraping Article 442 ---
#
# --- Scraping Article 443 ---
#
# --- Scraping Article 444 ---
#
# --- Scraping Article 445 ---
#
# --- Scraping Article 446 ---
#
# --- Scraping Article 447 ---
#
# --- Scraping Article 448 ---
#
# --- Scraping Article 449 ---
#
# --- Scraping Article 450 ---
#
# --- Scraping Article 451 ---
#
# --- Scraping Article 452 ---
#
# --- Scraping Article 453 ---
#
# --- Scraping Article 454 ---
#
# --- Scraping Article 455 ---
#
# --- Scraping Article 456 ---
#
# --- Scraping Article 457 ---
#
# --- Scraping Article 458 ---
#
# --- Scraping Article 459 ---
#
# --- Scraping Article 460 ---
#
# --- Scraping Article 461 ---
#
# --- Scraping Article 462 ---
#
# --- Scraping Article 463 ---
#
# --- Scraping Article 464 ---
#
# --- Scraping Article 465 ---
#
# --- Scraping Article 466 ---
#
# --- Scraping Article 467 ---
#
# --- Scraping Article 468 ---
#
# --- Scraping Article 469 ---
#
# --- Scraping Article 470 ---
#
# --- Scraping Article 471 ---
#
# --- Scraping Article 472 ---
#
# --- Scraping Article 473 ---
#
# --- Scraping Article 474 ---
#
# --- Scraping Article 475 ---
#
# --- Scraping Article 476 ---
#
# --- Scraping Article 477 ---
#
# --- Scraping Article 478 ---
#
# --- Scraping Article 479 ---
#
# --- Scraping Article 480 ---
#
# --- Scraping Article 481 ---
#
# --- Scraping Article 482 ---
#
# --- Scraping Article 483 ---
#
# --- Scraping Article 484 ---
#
# --- Scraping Article 485 ---
#
# --- Scraping Article 486 ---
#
# --- Scraping Article 487 ---
#
# --- Scraping Article 488 ---
#
# --- Scraping Article 489 ---
#
# --- Scraping Article 490 ---
#
# --- Scraping Article 491 ---
#
# --- Scraping Article 492 ---
#
# --- Scraping Article 493 ---
#
# --- Scraping Article 494 ---
#
# --- Scraping Article 495 ---
#
# --- Scraping Article 496 ---
#
# --- Scraping Article 497 ---
#
# --- Scraping Article 498 ---
#
# --- Scraping Article 499 ---
#
# --- Scraping Article 500 ---
#
# --- Scraping Article 501 ---
#
# --- Scraping Article 502 ---
#
# --- Scraping Article 503 ---
#
# --- Scraping Article 504 ---
#
# --- Scraping Article 505 ---
#
# --- Scraping Article 506 ---
#
# --- Scraping Article 507 ---
#
# --- Scraping Article 508 ---
#
# --- Scraping Article 509 ---
#
# --- Scraping Article 510 ---
#
# --- Scraping Article 511 ---
#
# --- Scraping Article 512 ---
#
# --- Scraping Article 513 ---
#
# --- Scraping Article 514 ---
#
# --- Scraping Article 515 ---
#
# --- Scraping Article 516 ---
#
# --- Scraping Article 517 ---
#
# --- Scraping Article 518 ---
#
# --- Scraping Article 519 ---
#
# --- Scraping Article 520 ---
#
# --- Scraping Article 521 ---
#
# --- Scraping Article 522 ---
#
# --- Scraping Article 523 ---
#
# --- Scraping Article 524 ---
#
# --- Scraping Article 525 ---
#
# --- Scraping Article 526 ---
#
# --- Scraping Article 527 ---
#
# --- Scraping Article 528 ---
#
# --- Scraping Article 529 ---
#
# --- Scraping Article 530 ---
#
# --- Scraping Article 531 ---
#
# --- Scraping Article 532 ---
#
# --- Scraping Article 533 ---
#
# --- Scraping Article 534 ---
#
# --- Scraping Article 535 ---
#
# --- Scraping Article 536 ---
#
# --- Scraping Article 537 ---
#
# --- Scraping Article 538 ---
#
# --- Scraping Article 539 ---
#
# --- Scraping Article 540 ---
#
# --- Scraping Article 541 ---
#
# --- Scraping Article 542 ---
#
# --- Scraping Article 543 ---
#
# --- Scraping Article 544 ---
#
# --- Scraping Article 545 ---
#
# --- Scraping Article 546 ---
#
# --- Scraping Article 547 ---
#
# --- Scraping Article 548 ---
#
# --- Scraping Article 549 ---
#
# --- Scraping Article 550 ---
#
# --- Scraping Article 551 ---
#
# --- Scraping Article 552 ---
#
# --- Scraping Article 553 ---
#
# --- Scraping Article 554 ---
#
# --- Scraping Article 555 ---
#
# --- Scraping Article 556 ---
#
# --- Scraping Article 557 ---
#
# --- Scraping Article 558 ---
#
# --- Scraping Article 559 ---
#
# --- Scraping Article 560 ---
#
# --- Scraping Article 561 ---
#
# --- Scraping Article 562 ---
#
# --- Scraping Article 563 ---
#
# --- Scraping Article 564 ---
#
# --- Scraping Article 565 ---
#
# --- Scraping Article 566 ---
#
# --- Scraping Article 567 ---
#
# --- Scraping Article 568 ---
#
# --- Scraping Article 569 ---
#
# --- Scraping Article 570 ---
#
# --- Scraping Article 571 ---
#
# --- Scraping Article 572 ---
#
# --- Scraping Article 573 ---
#
# --- Scraping Article 574 ---
#
# --- Scraping Article 575 ---
#
# --- Scraping Article 576 ---
#
# --- Scraping Article 577 ---
#
# --- Scraping Article 578 ---
#
# --- Scraping Article 579 ---
#
# --- Scraping Article 580 ---
#
# --- Scraping Article 581 ---
#
# --- Scraping Article 582 ---
#
# --- Scraping Article 583 ---
#
# --- Scraping Article 584 ---
#
# --- Scraping Article 585 ---
#
# --- Scraping Article 586 ---
#
# --- Scraping Article 587 ---
#
# --- Scraping Article 588 ---
#
# --- Scraping Article 589 ---
#
# --- Scraping Article 590 ---
#
# --- Scraping Article 591 ---
#
# --- Scraping Article 592 ---
#
# --- Scraping Article 593 ---
#
# --- Scraping Article 594 ---
#
# --- Scraping Article 595 ---
#
# --- Scraping Article 596 ---
#
# --- Scraping Article 597 ---
#
# --- Scraping Article 598 ---
#
# --- Scraping Article 599 ---
#
# --- Scraping Article 600 ---
#
# --- Scraping Article 601 ---
#
# --- Scraping Article 602 ---
#
# --- Scraping Article 603 ---
#
# --- Scraping Article 604 ---
#
# --- Scraping Article 605 ---
#
# --- Scraping Article 606 ---
#
# --- Scraping Article 607 ---
#
# --- Scraping Article 608 ---
#
# --- Scraping Article 609 ---
#
# --- Scraping Article 610 ---
#
# --- Scraping Article 611 ---
#
# --- Scraping Article 612 ---
#
# --- Scraping Article 613 ---
#
# --- Scraping Article 614 ---
#
# --- Scraping Article 615 ---
#
# --- Scraping Article 616 ---
#
# --- Scraping Article 617 ---
#
# --- Scraping Article 618 ---
#
# --- Scraping Article 619 ---
#
# --- Scraping Article 620 ---
#
# --- Scraping Article 621 ---
#
# --- Scraping Article 622 ---
#
# --- Scraping Article 623 ---
#
# --- Scraping Article 624 ---
#
# --- Scraping Article 625 ---
#
# --- Scraping Article 626 ---
#
# --- Scraping Article 627 ---
#
# --- Scraping Article 628 ---
#
# --- Scraping Article 629 ---
#
# --- Scraping Article 630 ---
#
# --- Scraping Article 631 ---
#
# --- Scraping Article 632 ---
