# %% [markdown]
# ### Download [Arxiv Dataset from HuggingFace](https://huggingface.co/datasets/mlcore/arxiv-classifier)

# %%
import pandas as pd

splits = {'train': 'minor/train.json', 'test': 'minor/test.json'}
#df = pd.read_json("hf://datasets/mlcore/arxiv-classifier/" + splits["train"], lines=True)
df = pd.read_csv("arxiv-minor-dataset.txt")

# %%
df = df.drop(columns=['Unnamed: 0'])

# %% [markdown]
# ### Segmentation

# %%
from wtpsplit import SaT
sat_sm = SaT("sat-3l-sm")

# %%
split_iterator = sat_sm.split(df['fulltext'].tolist()[:2], do_paragraph_segmentation=True)

# %%
for split in split_iterator:
  print(type(split))
  print(split)
# Out:
# <class 'list'>
# ...

# %% [markdown]
# ### Embeddings

# %%
# !pip install datasets
# !pip install transformers
# %pip install -U sentence-transformers

from sentence_transformers import SentenceTransformer
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 268.8/268.8 KB 5.3 MB/s eta 0:00:00a 0:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 30.8 MB/s eta 0:00:00a 0:00:01
# ...
# Note: you may need to restart the kernel to use updated packages.
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.0.2 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "/Users/denizbt/opt/anaconda3/lib/python3.9/runpy.py", line 197, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "/Users/denizbt/opt/anaconda3/lib/python3.9/runpy.py", line 87, in _run_code
#     exec(code, run_globals)
# ...

# %%
model = SentenceTransformer("allenai/scibert_scivocab_uncased")
data = ... # output of segmentation
embeddings = model.encode(data) # pass these into classification

# %% [markdown]
# #### Equation Embeddings
# TODO Eric

# %% [markdown]
# ### Classification
